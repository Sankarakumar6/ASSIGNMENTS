# %%
##1. Read the demand transaction file and print the first 15 rows and dtypes
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("Demand_tnx.csv")
data
# Out:
#             City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0      Hyderabad         Take Away              9978        7/31/2018
# 1      Hyderabad         Take Away              4064        7/31/2018
# 2      Hyderabad         Main Hall               965        7/31/2018
# 3      Hyderabad           Express              9978        7/31/2018
# 4      Hyderabad           Express              1045        7/31/2018
# ...          ...               ...               ...              ...
# 30226     Mumbai         Take Away              4056         8/1/2016
# 30227     Mumbai         Take Away              4058         8/1/2016
# 30228     Mumbai           Dine-in               964         8/1/2016
# 30229     Mumbai         Take Away              4066         8/1/2016
# 30230     Mumbai          Delivery              4061         8/1/2016
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# ...

# %%
data.tail(15)
# Out:
#          City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 30216  Mumbai         Take Away              4065         8/1/2016
# 30217  Mumbai         Take Away              4059         8/1/2016
# 30218  Mumbai          Delivery              4056         8/1/2016
# 30219  Mumbai          Delivery              4059         8/1/2016
# 30220  Mumbai         Take Away              4068         8/1/2016
# 30221  Mumbai          Delivery              4066         8/1/2016
# 30222  Mumbai         Main Hall               970         8/1/2016
# 30223  Mumbai         Main Hall               971         8/1/2016
# 30224  Mumbai          Delivery              4062         8/1/2016
# 30225  Mumbai         Take Away              4063         8/1/2016
# 30226  Mumbai         Take Away              4056         8/1/2016
# 30227  Mumbai         Take Away              4058         8/1/2016
# 30228  Mumbai           Dine-in               964         8/1/2016
# ...

# %%
data.dtypes
# Out:
# City                                           object
# Mapped_Sales_Type                              object
# Mapped_Item_Code                                int64
# Transaction_Date                               object
# Quantity_Sold                                   int64
# Median_Price                                  float64
# Average_Tax_Percent                           float64
# Effective_Price                               float64
# Percent_Quantity_With_Discount                float64
# Avg_Discount_Percent_On_Discounted_Items      float64
# Year                                            int64
# Month                                           int64
# Day                                            object
# Car_sales                                     float64
# F_and_B_Inflation                             float64
# F_and_B_Inflation_Adjusted_Effective_Price    float64
# F_and_B_Inflation_Adjusted_Median_Price       float64
# ...

# %%
#2. Convert the transaction date column to a date column using pd.to_datetime function
data["Transaction_Date"] = pd.to_datetime(data.Transaction_Date, format ="%m/%d/%Y")
data.dtypes
# Out:
# City                                                  object
# Mapped_Sales_Type                                     object
# Mapped_Item_Code                                       int64
# Transaction_Date                              datetime64[ns]
# Quantity_Sold                                          int64
# Median_Price                                         float64
# Average_Tax_Percent                                  float64
# Effective_Price                                      float64
# Percent_Quantity_With_Discount                       float64
# Avg_Discount_Percent_On_Discounted_Items             float64
# Year                                                   int64
# Month                                                  int64
# Day                                                   object
# Car_sales                                            float64
# F_and_B_Inflation                                    float64
# ...

# %%
#3. Subset the dataframe for transaction date greater than '2016-08-01'

data_trans_date = data[data['Transaction_Date'] > '2016-08-01']

# %%
data["Transaction_Date"].shape
# Out:
# (30231,)

# %%
data_trans_date["Transaction_Date"].shape
# Out:
# (30192,)

# %%
#4. Look for unique values in Mapped_Sales_Type

data["Mapped_Sales_Type"].describe(include = "all")
data["Mapped_Sales_Type"].unique()
# Out:
# array(['Take Away', 'Main Hall', 'Express', 'Delivery', 'Dine-in',
#        'Bakery'], dtype=object)

# %%
#5. Subset the entire dataframe, based on the below condition, to a new dataframe and work
#on the following questions
#a. Condition: Avg_Discount_Percent_On_Discounted_Items should be less than 1.0
#b. Check for sanity if the new dataframe contains
#Avg_Discount_Percent_On_Discounted_Items greater than or equal to 1.0


data_discount = data[data["Avg_Discount_Percent_On_Discounted_Items"] < 1.0]

# %%
data_discount["Avg_Discount_Percent_On_Discounted_Items"].describe(include= "all")
# Out:
# count    8902.000000
# mean        0.240715
# std         0.230171
# min         0.002952
# 25%         0.105007
# 50%         0.118004
# 75%         0.241047
# max         0.997939
# Name: Avg_Discount_Percent_On_Discounted_Items, dtype: float64

# %% [markdown]
# #by using decribe we can get min & max one way of checking

# %%
data_discount[data_discount['Avg_Discount_Percent_On_Discounted_Items'] >1.0]
# Out:
# Empty DataFrame
# Columns: [City, Mapped_Sales_Type, Mapped_Item_Code, Transaction_Date, Quantity_Sold, Median_Price, Average_Tax_Percent, Effective_Price, Percent_Quantity_With_Discount, Avg_Discount_Percent_On_Discounted_Items, Year, Month, Day, Car_sales, F_and_B_Inflation, F_and_B_Inflation_Adjusted_Effective_Price, F_and_B_Inflation_Adjusted_Median_Price, First_Week_Of_The_Month_Dummy, Last_Week_Of_The_Month_Dummy, Day_Of_The_Week_Seasonality, Month_Of_The_Year_Seasonality, Two_Wheeler_sales]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# #another way of checking entered code was correct or not

# %%
#6. Groupby 'City', 'Mapped_Sales_Type', 'Mapped_Item_Code', 'Transaction_Date' and
#perform following aggregate operations on respective columns as mentioned (note: Only
#one groupby to do all the below aggregations)
#a. Quantity_Sold – sum
#b. Median_Price – median
#c. Effective_Price – median

# %%
grouped_data = data.groupby(["City","Mapped_Sales_Type","Mapped_Item_Code","Transaction_Date"]).agg({"Quantity_Sold": "sum", "Median_Price": "median", "Effective_Price": "median"})
grouped_data
# Out:
#                                                              Quantity_Sold  \
# City    Mapped_Sales_Type Mapped_Item_Code Transaction_Date
# Chennai Bakery            4057             8/5/2017                    110
#                           9978             1/22/2018                   105
#         Delivery          4055             1/1/2018                    714
#                                            1/10/2018                   567
#                                            1/11/2018                   499
# ...                                                                    ...
# Mumbai  Take Away         4068             9/5/2016                    200
#                                            9/6/2016                    210
#                                            9/7/2016                    209
#                                            9/8/2016                    193
#                                            9/9/2016                    256
#
# ...

# %%
#7. Display the data for Effective_Price = not null and just print the last 5 rows (hint: use .notnull
#function)

price= data["Effective_Price"].notnull()

# %%
price.tail(5)
# Out:
# 30226    True
# 30227    True
# 30228    True
# 30229    True
# 30230    True
# Name: Effective_Price, dtype: bool

# %%
#8. Display the data for city = Chennai AND Mapped_Sales_Type = Delivery and print top 5
#records (hint use loc function to subset, then “&” operator to filter both the above cities)


data.loc[(data["City"] == 'Chennai') & (data["Mapped_Sales_Type"] == 'Delivery')]
# Out:
#           City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 8379   Chennai          Delivery              4055         2/5/2018
# 8384   Chennai          Delivery              4068         2/5/2018
# 8387   Chennai          Delivery              4064         2/5/2018
# 8388   Chennai          Delivery              4058         2/5/2018
# 8392   Chennai          Delivery              4061         2/5/2018
# ...        ...               ...               ...              ...
# 16606  Chennai          Delivery              4057         8/4/2017
# 16609  Chennai          Delivery              4056         8/4/2017
# 16611  Chennai          Delivery              4059         8/4/2017
# 16612  Chennai          Delivery              4063         8/4/2017
# 16614  Chennai          Delivery              4066         8/4/2017
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# 8379             544        281.10                 0.05       262.502194
# ...

# %%
#9. Display the data for the column “Day” with values Mon, Tue and Wed (hint: use .isin
#function)


data[data["Day"].isin(["Mon","Tue","Wed"])]
# Out:
#             City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0      Hyderabad         Take Away              9978        7/31/2018
# 1      Hyderabad         Take Away              4064        7/31/2018
# 2      Hyderabad         Main Hall               965        7/31/2018
# 3      Hyderabad           Express              9978        7/31/2018
# 4      Hyderabad           Express              1045        7/31/2018
# ...          ...               ...               ...              ...
# 30226     Mumbai         Take Away              4056         8/1/2016
# 30227     Mumbai         Take Away              4058         8/1/2016
# 30228     Mumbai           Dine-in               964         8/1/2016
# 30229     Mumbai         Take Away              4066         8/1/2016
# 30230     Mumbai          Delivery              4061         8/1/2016
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# ...

# %%
#10. Display the data for Percent_Quantity_With_Discount not equal to 0.0 (hint: loc function
#with != operator)

data.loc[(data["Percent_Quantity_With_Discount"] != 0.0)]
# Out:
#             City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0      Hyderabad         Take Away              9978        7/31/2018
# 1      Hyderabad         Take Away              4064        7/31/2018
# 2      Hyderabad         Main Hall               965        7/31/2018
# 3      Hyderabad           Express              9978        7/31/2018
# 4      Hyderabad           Express              1045        7/31/2018
# ...          ...               ...               ...              ...
# 30226     Mumbai         Take Away              4056         8/1/2016
# 30227     Mumbai         Take Away              4058         8/1/2016
# 30228     Mumbai           Dine-in               964         8/1/2016
# 30229     Mumbai         Take Away              4066         8/1/2016
# 30230     Mumbai          Delivery              4061         8/1/2016
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# ...

# %%
#11. Add a column “Range” to the existing dataframe for below condition
#a. 1 for Effective_Price > 500
#b. 0.5 otherwise
data.loc[data["Effective_Price"] >= 500,"Range"] = "1"
data.loc[data["Effective_Price"] < 500, "Range"] = "0.5"
data.head(15)

# %%
# Out:
#          City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0   Hyderabad         Take Away              9978       2018-07-31
# 1   Hyderabad         Take Away              4064       2018-07-31
# 2   Hyderabad         Main Hall               965       2018-07-31
# 3   Hyderabad           Express              9978       2018-07-31
# 4   Hyderabad           Express              1045       2018-07-31
# 5   Hyderabad          Delivery              4056       2018-07-31
# 6   Hyderabad         Take Away              4065       2018-07-31
# 7   Hyderabad           Express              4058       2018-07-31
# 8   Hyderabad           Express              4057       2018-07-31
# 9   Hyderabad           Express              4056       2018-07-31
# 10  Hyderabad          Delivery              4061       2018-07-31
# 11  Hyderabad           Express              4055       2018-07-31
# 12  Hyderabad         Take Away              4061       2018-07-31
# ...

# %% [markdown]
# # 12. Read the demand transaction file again and perform following operations for practice
# a. Handle the missing values in the column Percent_Quantity_With_Discount with
# strategy = mean
# b. One hot encode the columns Mapped_Sales_Type
# c. Label binarize the column Day
# d. Label encode the column City
# Please complete the given task and upload in your respective Github by 25/2/23

# %%
df_data = pd.read_csv("Demand_tnx.csv")

# %%
df_data.head(15)
# Out:
#          City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0   Hyderabad         Take Away              9978        7/31/2018
# 1   Hyderabad         Take Away              4064        7/31/2018
# 2   Hyderabad         Main Hall               965        7/31/2018
# 3   Hyderabad           Express              9978        7/31/2018
# 4   Hyderabad           Express              1045        7/31/2018
# 5   Hyderabad          Delivery              4056        7/31/2018
# 6   Hyderabad         Take Away              4065        7/31/2018
# 7   Hyderabad           Express              4058        7/31/2018
# 8   Hyderabad           Express              4057        7/31/2018
# 9   Hyderabad           Express              4056        7/31/2018
# 10  Hyderabad          Delivery              4061        7/31/2018
# 11  Hyderabad           Express              4055        7/31/2018
# 12  Hyderabad         Take Away              4061        7/31/2018
# ...

# %%
df1 =  df_data.copy()

# %%
df1
# Out:
#             City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0      Hyderabad         Take Away              9978        7/31/2018
# 1      Hyderabad         Take Away              4064        7/31/2018
# 2      Hyderabad         Main Hall               965        7/31/2018
# 3      Hyderabad           Express              9978        7/31/2018
# 4      Hyderabad           Express              1045        7/31/2018
# ...          ...               ...               ...              ...
# 30226     Mumbai         Take Away              4056         8/1/2016
# 30227     Mumbai         Take Away              4058         8/1/2016
# 30228     Mumbai           Dine-in               964         8/1/2016
# 30229     Mumbai         Take Away              4066         8/1/2016
# 30230     Mumbai          Delivery              4061         8/1/2016
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# ...

# %%
df_data['Percent_Quantity_With_Discount'].isna().value_counts()
# Out:
# True     18022
# False    12209
# Name: Percent_Quantity_With_Discount, dtype: int64

# %%
df1["Percent_Quantity_With_Discount"]   = df_data["Percent_Quantity_With_Discount"].fillna(df_data["Percent_Quantity_With_Discount"].mean())

# %%
df1["Percent_Quantity_With_Discount"].isna().value_counts()
# Out:
# False    30231
# Name: Percent_Quantity_With_Discount, dtype: int64

# %% [markdown]
# # One hot encode the columns Mapped_Sales

# %%
df1["Mapped_Sales_Type"].unique()
# Out:
# array(['Take Away', 'Main Hall', 'Express', 'Delivery', 'Dine-in',
#        'Bakery'], dtype=object)

# %%
pd.get_dummies(data = df1, columns =["Mapped_Sales_Type"])
# Out:
#             City  Mapped_Item_Code Transaction_Date  Quantity_Sold  \
# 0      Hyderabad              9978        7/31/2018            167
# 1      Hyderabad              4064        7/31/2018            368
# 2      Hyderabad               965        7/31/2018            694
# 3      Hyderabad              9978        7/31/2018            140
# 4      Hyderabad              1045        7/31/2018            139
# ...          ...               ...              ...            ...
# 30226     Mumbai              4056         8/1/2016            615
# 30227     Mumbai              4058         8/1/2016           1289
# 30228     Mumbai               964         8/1/2016            140
# 30229     Mumbai              4066         8/1/2016            179
# 30230     Mumbai              4061         8/1/2016            117
#
#        Median_Price  Average_Tax_Percent  Effective_Price  \
# 0             187.0                 0.05       163.700000
# ...

# %%
df1
# Out:
#             City Mapped_Sales_Type  Mapped_Item_Code Transaction_Date  \
# 0      Hyderabad         Take Away              9978        7/31/2018
# 1      Hyderabad         Take Away              4064        7/31/2018
# 2      Hyderabad         Main Hall               965        7/31/2018
# 3      Hyderabad           Express              9978        7/31/2018
# 4      Hyderabad           Express              1045        7/31/2018
# ...          ...               ...               ...              ...
# 30226     Mumbai         Take Away              4056         8/1/2016
# 30227     Mumbai         Take Away              4058         8/1/2016
# 30228     Mumbai           Dine-in               964         8/1/2016
# 30229     Mumbai         Take Away              4066         8/1/2016
# 30230     Mumbai          Delivery              4061         8/1/2016
#
#        Quantity_Sold  Median_Price  Average_Tax_Percent  Effective_Price  \
# ...

# %% [markdown]
# # Label binarize the column Day
